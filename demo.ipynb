# %% [markdown]
# ## PROBLEM STATEMENT

# %% [markdown]
# **Objective:**
#
# Illustrate Deep Learning concepts and their practical application by executing an end-to-end project, emphasizing hands-on learning through practical implementation.

# %% [markdown]
# **Project Details:**
#
# Object Detection through  labelled data using  Multi classification techniques taken from a MRI scan

# %% [markdown]
# **Milestone stages :**
#
# *Milestone 1 - Business Understanding*
#
# *Milestone 2 - Data understanding*
#
# *Milestone 3 - Data pre-processing*
#
# *Milestone 4 - Model building and evaluation*
#
# *Milestone 5 - Model deployment and monitoring*

# %% [markdown]
# **Context :**
#
# A quote from Dr. Devi Shetty,the Chairman of Narayana Health in Bangalore, from the conference at XIME Bangalore :
#  “Smart Software is smarter than the doctors. There are only 6,000 diseases, out of which there are 1,000 that are common.  There are about 50,000 signs and symptoms of these diseases. There are 100,000 types of lab reports. Matching these to diagnose a disease can be done by any software very easily, which takes a doctor years to practice.”
#
# Key reasons why we need disease diagnosis to be done by machines are:
#
# a.	Every year 195,000 patients in the US die of medical diagnostic error
#
# b.	Inability of a human being to process huge amounts of information,analyze it, and apply it to a particular disease diagnosis
#
# c.	Cloning of an expert robot is cheap and fast compared to a doctor, where cloning of expert human doctors is forbidden by law in many countries
#
# d.	Accuracy in diagnosis is critical, as an incorrect diagnosis increases the cost of healthcare for the patient.
#
# e.	Using machine learning, we can track, measure, optimize, learn, and improve
# based on feedback on the accuracy of diagnosis by a robot or a machine.
#
# f.	To increase the value of healthcare to its patients, it is an absolute must to decrease the cost of diagnosis given to a patient.
#
# g.	Value = Patient health outcome per dollar spent on the treatment.

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# **Project Objective:**
#
# Develop a machine learning system aimed at reducing diagnostic errors by selecting and optimizing classification metrics that align with the specific business objectives and goals.

# %% [markdown]
# **Milestone 1**       [**Weightage - 5%**]
#
# - Able to understand the problem statement.
# - Understand CRISP-DM framework
# - Design a deployable solution

# %% [markdown]
# **Business understanding**
#
#
# Insert your understanding and text here

# %% [markdown]
# **Milestone 2**    [**Weightage - 15%**]
#
# - Understanding about infrastructure
# - How to use GPU
# - Knowledge about different libraries available for DL and ML
# - Ability to analyze 3D image data
# - Ability to load image data into Jupyter notebook
# - Design a proper input format for the pipeline

# %% [markdown]
# **Data Understanding**
#
#
# STEPS REQUIRED TO BE DONE :
# - **Import required libraries, load the metadata**
# - **Evaluate the shape of the metadata uploaded**
# [Auto evaluation is going to be done for this, hence we need the participants to update the result in the function given below]

# %%
# write your codes here

# %%
#put the result in the below function

# Returns sample image size and sample mask size in a form of tuple, the first value is the image size and the second value is the mask size
def submit_sample_mask_image_size()->tuple:    
    img_shape = ()   #format to be used is (xxx, xxx, xxx)
    mask_shape = ()  #format to be used is (xxx, xxx, xxx)

    return img_shape,mask_shape

# %% [markdown]
# **Milestone 3:**  [**Weightage - 25%**]
#
# - Ability to analyse data and extract business relevant insights
# - Ability to merge data from different data sources
# - Ability to augment data
# - How to normalize, resize and reshape data.
# - Visualizing 3D data
# - Plotting 3D data
# - Creating data loaders
#
#
# **Data Pre-processing**

# %% [markdown]
# **Milestone 4:**   **[Weightage - 35%]**
#
#
# - ANN, CNN, Transfer Learning
# - Different Transfer Learning architectures.
# - Splitting data into train, test and validation
# - Switching model processing between CPU and GPU
# - Understand Loss Functions,
# - Forward backward propagations,
# - Different optimizers and their application
# - Ability to implement and interpret different evaluation metrices
# - Ability to choose suitable metric for a given problem statement
# - Hyper parameter tuning
#
#
# **Model building and evaluation**

# %%
def submit_accuracy_precision_recall_f1score()->tuple:
    #Set the values here
    model_accuracy = ________    #put the metrics as floating points in the function
    model_precision = ________
    model_recall = ________
    model_f1score = ________
    # setting value ends
    return model_accuracy,model_precision,model_recall,model_f1score

# %% [markdown]
# **Milestone 5:**   **[Weightage - 20%]**
#
# - Model deployment technologies.
# - Story telling using data.
#
#
# **Model Deployment and monitoring**

# %% [markdown]
# **| ********************************************************* END OF CAPSTONE **************************************************************** |**
#
# You can now submit the attempt and click on complete assessment
#
# NOTE : Once you click on complete assessment you cannot edit any of your milestones further    **[Complete assesment = Final submission]**
